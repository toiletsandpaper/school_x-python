# %%
# %pip install -Uq sympy
# Out:
# [notice] A new release of pip is available: 23.0 -> 23.2.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sympy as sp

# %%
x = sp.symbols('x')

# %%
equation = (9*x**2 + 4*x + 2)
equation
# Out:
# 9*x**2 + 4*x + 2

# %% [markdown]
# $$ \left(x - 10\right)^{2} $$

# %%
sp.diff(equation)
# Out:
# 18*x + 4

# %%
def antigrad(x):
    return 18*x + 4

# %%
x = 100  # 10
lr = 0.1

for i in range(200):
    x = x - lr * antigrad(x)
    print(f'x{i} = {x}')
x
# Out:
# x0 = -80.4
# x1 = 63.920000000000016
# x2 = -51.53600000000003
# x3 = 40.82880000000003
# x4 = -33.063040000000015
# x5 = 26.050432000000015
# x6 = -21.240345600000012
# x7 = 16.59227648000001
# x8 = -13.673821184000008
# x9 = 10.539056947200006
# x10 = -8.831245557760006
# x11 = 6.664996446208008
# x12 = -5.731997156966408
# x13 = 4.1855977255731265
# x14 = -3.748478180458501
# x15 = 2.5987825443668005
# x16 = -2.4790260354934404
# x17 = 1.5832208283947526
# x18 = -1.6665766627158018
# x19 = 0.9332613301726416
# x20 = -1.1466090641381133
# x21 = 0.5172872513104907
# x22 = -0.8138298010483926
# x23 = 0.251063840838714
# x24 = -0.6008510726709714
# x25 = 0.08068085813677706
# x26 = -0.4645446865094216
# x27 = -0.02836425079246263
# x28 = -0.3773085993660299
# x29 = -0.09815312050717606
# x30 = -0.32147750359425914
# x31 = -0.1428179971245927
# x32 = -0.28574560230032586
# x33 = -0.17140351815973928
# x34 = -0.26287718547220856
# x35 = -0.1896982516222331
# x36 = -0.2482413987022135
# ...

# %%
antigrad(-0.222)
# Out:
# 0.0040000000000000036

# %%
x = -0.22
(9*x**2 + 4*x + 2)
# Out:
# 1.5556
